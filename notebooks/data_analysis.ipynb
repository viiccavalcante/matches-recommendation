# %%
import pandas as pd
df = pd.read_csv('../data/dating_app_behavior.csv')
df.head(3)
# Out:
#               gender sexual_orientation location_type income_bracket  \
# 0  Prefer Not to Say                Gay         Urban           High
# 1               Male           Bisexual      Suburban   Upper-Middle
# 2         Non-binary          Pansexual      Suburban            Low
#
#        education_level                  interest_tags  app_usage_time_min  \
# 0           Bachelor’s   Fitness, Politics, Traveling                  52
# 1  No Formal Education  Languages, Fashion, Parenting                 279
# 2             Master’s           Movies, Reading, DIY                  49
#
#   app_usage_time_label  swipe_right_ratio swipe_right_label  ...  \
# 0             Moderate               0.60        Optimistic  ...
# 1         Extreme User               0.56        Optimistic  ...
# 2             Moderate               0.41        Optimistic  ...
#
#    emoji_usage_rate  last_active_hour  swipe_time_of_day  match_outcome  age  \
# ...

# %%
df.isnull().sum()
# Out:
# gender                  0
# sexual_orientation      0
# location_type           0
# income_bracket          0
# education_level         0
# interest_tags           0
# app_usage_time_min      0
# app_usage_time_label    0
# swipe_right_ratio       0
# swipe_right_label       0
# likes_received          0
# mutual_matches          0
# profile_pics_count      0
# bio_length              0
# message_sent_count      0
# emoji_usage_rate        0
# last_active_hour        0
# swipe_time_of_day       0
# match_outcome           0
# age                     0
# height_cm               0
# weight_kg               0
# zodiac_sign             0
# body_type               0
# relationship_intent     0
# dtype: int64

# %%
df.describe()
# Out:
#        app_usage_time_min  swipe_right_ratio  likes_received  mutual_matches  \
# count        50000.000000       50000.000000    50000.000000    50000.000000
# mean           149.912400           0.500655       99.526040       13.870280
# std             86.990521           0.197468       57.996799        9.105615
# min              0.000000           0.000000        0.000000        0.000000
# 25%             74.000000           0.370000       49.000000        6.000000
# 50%            150.000000           0.500000      100.000000       13.000000
# 75%            225.000000           0.640000      150.000000       22.000000
# max            300.000000           1.000000      200.000000       30.000000
#
#        profile_pics_count    bio_length  message_sent_count  emoji_usage_rate  \
# count         50000.00000  50000.000000         50000.00000      50000.000000
# mean              2.98772    250.174400            50.07194          0.286205
# ...

# %%
df.columns
# Out:
# Index(['gender', 'sexual_orientation', 'location_type', 'income_bracket',
#        'education_level', 'interest_tags', 'app_usage_time_min',
#        'app_usage_time_label', 'swipe_right_ratio', 'swipe_right_label',
#        'likes_received', 'mutual_matches', 'profile_pics_count', 'bio_length',
#        'message_sent_count', 'emoji_usage_rate', 'last_active_hour',
#        'swipe_time_of_day', 'match_outcome', 'age', 'height_cm', 'weight_kg',
#        'zodiac_sign', 'body_type', 'relationship_intent'],
#       dtype='object')

# %%
categorical_features= ['gender', 'sexual_orientation', 'location_type', 'income_bracket', 'education_level', 
                       'interest_tags', 'app_usage_time_label', 'swipe_right_label', 'swipe_time_of_day', 'match_outcome', 'relationship_intent']

for feature in categorical_features:
    print(f"Unique {feature}: {df[feature].unique()}")
    print(f"Number of unique values{feature}: {df[feature].nunique()}\n")
# Out:
# Unique gender: ['Prefer Not to Say' 'Male' 'Non-binary' 'Genderfluid' 'Female'
#  'Transgender']
# Number of unique valuesgender: 6
#
# Unique sexual_orientation: ['Gay' 'Bisexual' 'Pansexual' 'Lesbian' 'Asexual' 'Queer' 'Straight'
#  'Demisexual']
# Number of unique valuessexual_orientation: 8
#
# Unique location_type: ['Urban' 'Suburban' 'Metro' 'Small Town' 'Remote Area' 'Rural']
# Number of unique valueslocation_type: 6
#
# Unique income_bracket: ['High' 'Upper-Middle' 'Low' 'Very Low' 'Middle' 'Lower-Middle'
#  'Very High']
# Number of unique valuesincome_bracket: 7
#
# Unique education_level: ['Bachelor’s' 'No Formal Education' 'Master’s' 'Postdoc' 'Associate’s'
#  'High School' 'Diploma' 'PhD' 'MBA']
# Number of unique valueseducation_level: 9
#
# Unique interest_tags: ['Fitness, Politics, Traveling' 'Languages, Fashion, Parenting'
#  'Movies, Reading, DIY' ... 'Traveling, Fitness, Stand-up Comedy'
#  'Gaming, Motorcycling, Art' 'Skating, Astrology, Hiking']
# ...
